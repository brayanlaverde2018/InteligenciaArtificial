# %% [markdown]
# # PROYECTO DE IA CORTE 1

# %% [markdown]
# #### Se importan las librerías Numpy y Pandas para la manipulación y el análisis de los datos, también se importa la libreria matplotlib y seaborn para la graficación de los datos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action="ignore")
import seaborn as sns
import pylab as pl

# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_moons
import matplotlib.gridspec as gridspec

# %% [markdown]
# #### Se procede a cargar la hoja con los datos ceparados por coma

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %% [markdown]
# #### Se cambia el nombre de las columnas a español

# %%
df.rename(columns={'gender':'Género','race/ethnicity':'Etnia','lunch':'Almuerzo','test preparation course':'Exámen de Preparación',
                   'parental level of education':'Educación Parental','math score':'Puntaje Matemáticas',
                   'reading score':'Puntaje de Lectura','writing score':'Puntaje de Escritura'},inplace=True);
df.columns
# Out:
# Index(['Género', 'Etnia', 'Educación Parental', 'Almuerzo',
#        'Exámen de Preparación', 'Puntaje Matemáticas', 'Puntaje de Lectura',
#        'Puntaje de Escritura'],
#       dtype='object')

# %% [markdown]
# #### Se visualizan los cinco primeros datos que muestra por defecto .head()

# %%
df.head()
# Out:
#    Género    Etnia  Educación Parental      Almuerzo Exámen de Preparación  \
# 0  female  group B   bachelor's degree      standard                  none
# 1  female  group C        some college      standard             completed
# 2  female  group B     master's degree      standard                  none
# 3    male  group A  associate's degree  free/reduced                  none
# 4    male  group C        some college      standard                  none
#
#    Puntaje Matemáticas  Puntaje de Lectura  Puntaje de Escritura
# 0                   72                  72                    74
# 1                   69                  90                    88
# 2                   90                  95                    93
# 3                   47                  57                    44
# 4                   76                  78                    75

# %% [markdown]
# #### Se visualizan los ultimos cinco datos que muestra por defecto .tal()

# %%
df.tail()
# Out:
#      Género    Etnia Educación Parental      Almuerzo Exámen de Preparación  \
# 995  female  group E    master's degree      standard             completed
# 996    male  group C        high school  free/reduced                  none
# 997  female  group C        high school  free/reduced             completed
# 998  female  group D       some college      standard             completed
# 999  female  group D       some college  free/reduced                  none
#
#      Puntaje Matemáticas  Puntaje de Lectura  Puntaje de Escritura
# 995                   88                  99                    95
# 996                   62                  55                    55
# 997                   59                  71                    65
# 998                   68                  78                    77
# 999                   77                  86                    86

# %% [markdown]
# #### Se visualizan el número de filas y columnas

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# #### Se procede a visualizar la información del DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Género                 1000 non-null   object
#  1   Etnia                  1000 non-null   object
#  2   Educación Parental     1000 non-null   object
#  3   Almuerzo               1000 non-null   object
#  4   Exámen de Preparación  1000 non-null   object
#  5   Puntaje Matemáticas    1000 non-null   int64
#  6   Puntaje de Lectura     1000 non-null   int64
#  7   Puntaje de Escritura   1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# #### Se obtienen algunos valores estadísticos de los datos a través de describe()

# %%
df.describe()
# Out:
#        Puntaje Matemáticas  Puntaje de Lectura  Puntaje de Escritura
# count           1000.00000         1000.000000           1000.000000
# mean              66.08900           69.169000             68.054000
# std               15.16308           14.600192             15.195657
# min                0.00000           17.000000             10.000000
# 25%               57.00000           59.000000             57.750000
# 50%               66.00000           70.000000             69.000000
# 75%               77.00000           79.000000             79.000000
# max              100.00000          100.000000            100.000000

# %% [markdown]
# #### Revisión de datos unicos en cada columna

# %%
df.nunique()
# Out:
# Género                    2
# Etnia                     5
# Educación Parental        6
# Almuerzo                  2
# Exámen de Preparación     2
# Puntaje Matemáticas      81
# Puntaje de Lectura       72
# Puntaje de Escritura     77
# dtype: int64

# %% [markdown]
# #### Se procede a verificar si existen datos nulos

# %%
df.isnull().sum()
# Out:
# Género                   0
# Etnia                    0
# Educación Parental       0
# Almuerzo                 0
# Exámen de Preparación    0
# Puntaje Matemáticas      0
# Puntaje de Lectura       0
# Puntaje de Escritura     0
# dtype: int64

# %% [markdown]
# #### Se procede a contar y a graficar el número de estudiantes según su género

# %%
labels = df['Género'].value_counts().index
sizes = df['Género'].value_counts().values

plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Distribución de estudiantes por Género',color = 'black',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribución de estudiantes por Género')

# %% [markdown]
# #### Se procede a contar el número de estudiantes según su Etnia

# %%
labels = df['Etnia'].value_counts().index
sizes = df['Etnia'].value_counts().values

plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Distribución de estudiantes por Etnia',color = 'black',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribución de estudiantes por Etnia')

# %% [markdown]
# #### Se procede a identificar el nivel de educación de los padres

# %%
counts = df['Educación Parental'].value_counts()

plt.figure(figsize=(10,7))
sns.barplot(x=counts.index, y=counts.values, palette="Set3")


plt.xticks(rotation = 45, size = 12)
plt.yticks(rotation = 45, size = 12)

plt.title('Distribución de nivel de educación de los padres',color = 'black',fontsize=15)
plt.show()

# %% [markdown]
# #### Se procede a contar el número de estudiantes según el almuerzo que consumen

# %%
plt.bar(df["Almuerzo"].unique(),df["Almuerzo"].value_counts(),color=["purple"]);
print(df["Almuerzo"].value_counts())
plt.title('Tipo de almuerzo de los estudiantes',color = 'black',fontsize=15)
# Out:
# standard        645
# free/reduced    355
# Name: Almuerzo, dtype: int64
# Text(0.5, 1.0, 'Tipo de almuerzo de los estudiantes')

# %% [markdown]
# #### Se procede a contar el número de estudiantes que realizaron exámen de preparación y los que no lo hicieron

# %%
race_math = df[["Exámen de Preparación","Puntaje Matemáticas"]].groupby(["Exámen de Preparación"], as_index = False).mean()
race_writing = df[["Exámen de Preparación","Puntaje de Lectura"]].groupby(["Exámen de Preparación"], as_index = False).mean()
race_reading = df[["Exámen de Preparación","Puntaje de Escritura"]].groupby(["Exámen de Preparación"], as_index = False).mean()

plt.figure(figsize=(20,10))
plt.title('Exámen de Preparación por Materias', fontweight='bold', size = 24)

barWidth = 0.25
 
bars1 = race_math['Puntaje Matemáticas']
bars2 = race_writing['Puntaje de Lectura']
bars3 = race_reading['Puntaje de Escritura']
 
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
plt.bar(r1, bars1, color='blue', width=barWidth, edgecolor='white', label='Puntaje Matemáticas', yerr=0.5,ecolor="black",capsize=10)
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Puntaje de Lectura', yerr=0.5,ecolor="black",capsize=10, alpha = .50)
plt.bar(r3, bars3, color='red', width=barWidth, edgecolor='white', label='Puntaje de Escritura', yerr=0.5,ecolor="black",capsize=10, hatch = '-')
 
modelNames = race_math['Exámen de Preparación']
    
plt.xlabel('Exámen de Preparación', fontweight='bold', size = 24)
plt.ylabel('Puntajes', fontweight='bold', size = 24)
plt.xticks([r + barWidth for r in range(len(bars1))], modelNames, rotation = 0, size = 24)
 
plt.legend()
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# #### Se procede a generar una gráfica sobre las notas de cada una de las materias

# %%
plt.figure(figsize=(20,7))
sns.countplot(df['Puntaje Matemáticas'])
plt.xlabel("Puntaje Matemáticas",fontsize=20)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.countplot(df['Puntaje de Escritura'])
plt.xlabel("Puntaje de Escritura",fontsize=20)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.countplot(df['Puntaje de Lectura'])
plt.xlabel("Puntaje de Lectura",fontsize=20)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
df=df[["Género","Puntaje Matemáticas", "Puntaje de Lectura",
       "Puntaje de Escritura"]]

# %%
df.head()
# Out:
#    Género  Puntaje Matemáticas  Puntaje de Lectura  Puntaje de Escritura
# 0  female                   72                  72                    74
# 1  female                   69                  90                    88
# 2  female                   90                  95                    93
# 3    male                   47                  57                    44
# 4    male                   76                  78                    75

# %%
df=pd.get_dummies(df,columns=["Género"])

# %%
df.head()
# Out:
#    Puntaje Matemáticas  Puntaje de Lectura  Puntaje de Escritura  \
# 0                   72                  72                    74
# 1                   69                  90                    88
# 2                   90                  95                    93
# 3                   47                  57                    44
# 4                   76                  78                    75
#
#    Género_female  Género_male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              0            1
# 4              0            1

# %%
df.drop(["Género_male"],axis=1,inplace=True)

# %%
X=df[["Puntaje Matemáticas","Puntaje de Lectura"]]

# %%
Y=df["Género_female"]

# %%
X.head()
# Out:
#    Puntaje Matemáticas  Puntaje de Lectura
# 0                   72                  72
# 1                   69                  90
# 2                   90                  95
# 3                   47                  57
# 4                   76                  78

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: Género_female, dtype: uint8

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=3,random_state=0)

# %%
print(X_train.shape,Y_train.shape)
# Out:
# (750, 2) (750,)

# %%
print(X_test.shape,Y_test.shape)
# Out:
# (250, 2) (250,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier().fit(X_train,Y_train)
np.sqrt(mean_squared_error(Y_test,knn_model.predict(X_test)))
r2_score(Y_test,knn_model.predict(X_test))
accuracy_score(Y_test,knn_model.predict(X_test))
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
plt.figure(figsize=(16,8))
X_set, y_set = X_test, Y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, knn_model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.6, cmap = ListedColormap(('red', 'blue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
     plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                 c = ListedColormap(('red', 'blue'))(i), label = j)
font={"fontsize":15}
plt.title('KNN Test Seti',fontdict=font)
plt.xlabel('Math + Writing Score',fontdict=font)
plt.ylabel('Gender (Female=1,Male=0)',fontdict=font)
plt.legend(loc=2)
plt.show();
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
